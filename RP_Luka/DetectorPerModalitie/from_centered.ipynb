# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score
from sklearn.model_selection import train_test_split

def train_cross_modality_centered(
    train_modality: str,
    test_modality: str,
    duration_s: int,
    cfg: dict = None
):
    # 1) Hyperparameters
    defaults = {"n_estimators": 100, "max_depth": 10, "random_state": 42}
    params = defaults.copy()
    if cfg:
        params.update(cfg)

    # 2) Path to feature file
    def feature_path(mod):
        return f"./features/fixed_really/balanced/{mod}/features_{mod}_{duration_s}s_balanced.csv"

    # 3) Load data
    if train_modality == test_modality:
        df = pd.read_csv(feature_path(train_modality))
        df_tr, df_te = train_test_split(df, test_size=0.25, stratify=df["label"], random_state=params["random_state"])
    else:
        df_tr = pd.read_csv(feature_path(train_modality))
        df_te = pd.read_csv(feature_path(test_modality))

    # 4) Feature selection
    drop_cols = [
        "video_id","segment","participant","start_time","end_time","label",
        "original_cont_duration","duration_s","real_sample_count", "window_start_frame", "original_duration"
    ]
    feat_cols = sorted(set(df_tr.columns) - set(drop_cols))

    # 5) Construct matrices
    X_tr, y_tr = df_tr[feat_cols].fillna(0), df_tr["label"]
    X_te, y_te = df_te[feat_cols].fillna(0), df_te["label"]

    # 6) Train classifier
    clf = RandomForestClassifier(
        n_estimators=params["n_estimators"],
        max_depth=params["max_depth"],
        class_weight="balanced",
        random_state=params["random_state"],
        n_jobs=-1
    )
    clf.fit(X_tr, y_tr)
    preds = clf.predict(X_te)

    # 7) Metrics
    report = classification_report(y_te, preds, output_dict=True, zero_division=0)
    f1_macro = f1_score(y_te, preds, average="macro")
    report_1 = report.get("1", {"precision": 0, "recall": 0, "f1-score": 0})
    y_te_pos = (y_te == 1).sum()

    # 8) Feature importances
    importance_df = pd.DataFrame({
        "feature": feat_cols,
        "importance": clf.feature_importances_
    }).sort_values(by="importance", ascending=False)

    metrics = {
        "train_modality": train_modality,
        "test_modality":  test_modality,
        "duration_s":     duration_s,
        "accuracy":       report["accuracy"],
        "f1_macro":       f1_macro,
        "precision_1":    report_1["precision"],
        "recall_1":       report_1["recall"],
        "f1_1":           report_1["f1-score"],
        "y_te_positives": y_te_pos,
        "feature_importances": importance_df.reset_index(drop=True)
    }

    print(f"✅ {train_modality} → {test_modality} @ {duration_s}s | Positives in test set: {y_te_pos}")
    print("\n🔍 Top 10 most important features:")
    print(importance_df.head(10))
    return metrics

# %%
# %%
modalities = ["with_audio", "no_audio", "only_audio"]
durations  = [1, 2, 10]

results = []
for dur in durations:
    for train_mod in modalities:
        for test_mod in modalities:
            res = train_cross_modality_centered(
                train_modality=train_mod,
                test_modality=test_mod,
                duration_s=dur
            )
            results.append(res)

# Guardar resultados
df_results = pd.DataFrame(results)
df_results.to_csv("crossmod_centered_summary.csv", index=False)
df_results
# Out:
# ✅ with_audio → with_audio @ 1s | Positives in test set: 7003
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.074959
# 2   accelX_filtered_deriv_std    0.069893
# 12  accelZ_filtered_deriv_std    0.065920
# 17                    corr_xz    0.063784
# 13     accelZ_filtered_energy    0.058240
# 7   accelY_filtered_deriv_std    0.058056
# 0                         SMA    0.055742
# 8      accelY_filtered_energy    0.053562
# 15        accelZ_filtered_var    0.053317
# 16                    corr_xy    0.052490
# ✅ with_audio → no_audio @ 1s | Positives in test set: 27806
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.074785
# 12  accelZ_filtered_deriv_std    0.070165
# 2   accelX_filtered_deriv_std    0.065262
# 17                    corr_xz    0.064851
# 7   accelY_filtered_deriv_std    0.062498
# 16                    corr_xy    0.057827
# 13     accelZ_filtered_energy    0.055560
# 15        accelZ_filtered_var    0.055553
# 0                         SMA    0.054780
# 8      accelY_filtered_energy    0.053012
# ✅ with_audio → only_audio @ 1s | Positives in test set: 27955
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.074785
# 12  accelZ_filtered_deriv_std    0.070165
# 2   accelX_filtered_deriv_std    0.065262
# 17                    corr_xz    0.064851
# 7   accelY_filtered_deriv_std    0.062498
# 16                    corr_xy    0.057827
# 13     accelZ_filtered_energy    0.055560
# 15        accelZ_filtered_var    0.055553
# 0                         SMA    0.054780
# 8      accelY_filtered_energy    0.053012
# ✅ no_audio → with_audio @ 1s | Positives in test set: 28012
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.087076
# 12  accelZ_filtered_deriv_std    0.079999
# 16                    corr_xy    0.061426
# 17                    corr_xz    0.058619
# 5         accelX_filtered_var    0.055366
# 3      accelX_filtered_energy    0.053334
# 13     accelZ_filtered_energy    0.052308
# 7   accelY_filtered_deriv_std    0.052001
# 15        accelZ_filtered_var    0.049679
# 8      accelY_filtered_energy    0.049046
# ✅ no_audio → no_audio @ 1s | Positives in test set: 6951
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.087303
# 12  accelZ_filtered_deriv_std    0.078570
# 17                    corr_xz    0.060362
# 16                    corr_xy    0.058650
# 5         accelX_filtered_var    0.056322
# 7   accelY_filtered_deriv_std    0.056208
# 3      accelX_filtered_energy    0.054090
# 13     accelZ_filtered_energy    0.053115
# 15        accelZ_filtered_var    0.051460
# 2   accelX_filtered_deriv_std    0.048164
# ✅ no_audio → only_audio @ 1s | Positives in test set: 27955
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.087076
# 12  accelZ_filtered_deriv_std    0.079999
# 16                    corr_xy    0.061426
# 17                    corr_xz    0.058619
# 5         accelX_filtered_var    0.055366
# 3      accelX_filtered_energy    0.053334
# 13     accelZ_filtered_energy    0.052308
# 7   accelY_filtered_deriv_std    0.052001
# 15        accelZ_filtered_var    0.049679
# 8      accelY_filtered_energy    0.049046
# ✅ only_audio → with_audio @ 1s | Positives in test set: 28012
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 12  accelZ_filtered_deriv_std    0.067024
# 2   accelX_filtered_deriv_std    0.064101
# 3      accelX_filtered_energy    0.058141
# 18                    corr_yz    0.056523
# 7   accelY_filtered_deriv_std    0.056182
# 16                    corr_xy    0.055296
# 5         accelX_filtered_var    0.054493
# 17                    corr_xz    0.053712
# 13     accelZ_filtered_energy    0.052612
# 15        accelZ_filtered_var    0.052182
# ✅ only_audio → no_audio @ 1s | Positives in test set: 27806
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 12  accelZ_filtered_deriv_std    0.067024
# 2   accelX_filtered_deriv_std    0.064101
# 3      accelX_filtered_energy    0.058141
# 18                    corr_yz    0.056523
# 7   accelY_filtered_deriv_std    0.056182
# 16                    corr_xy    0.055296
# 5         accelX_filtered_var    0.054493
# 17                    corr_xz    0.053712
# 13     accelZ_filtered_energy    0.052612
# 15        accelZ_filtered_var    0.052182
# ✅ only_audio → only_audio @ 1s | Positives in test set: 6989
#
# 🔍 Top 10 most important features:
#                        feature  importance
# 2    accelX_filtered_deriv_std    0.067310
# 12   accelZ_filtered_deriv_std    0.062226
# 17                     corr_xz    0.057060
# 3       accelX_filtered_energy    0.056752
# 18                     corr_yz    0.056074
# 7    accelY_filtered_deriv_std    0.055267
# 16                     corr_xy    0.053677
# 5          accelX_filtered_var    0.053401
# 13      accelZ_filtered_energy    0.053398
# 6   accelY_filtered_deriv_mean    0.051988
# ✅ with_audio → with_audio @ 2s | Positives in test set: 7003
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.086125
# 17                    corr_xz    0.083461
# 2   accelX_filtered_deriv_std    0.080259
# 12  accelZ_filtered_deriv_std    0.078533
# 7   accelY_filtered_deriv_std    0.069913
# 0                         SMA    0.059905
# 16                    corr_xy    0.057616
# 10        accelY_filtered_var    0.057536
# 13     accelZ_filtered_energy    0.056488
# 15        accelZ_filtered_var    0.055185
# ✅ with_audio → no_audio @ 2s | Positives in test set: 27806
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.084960
# 2   accelX_filtered_deriv_std    0.083718
# 17                    corr_xz    0.083142
# 12  accelZ_filtered_deriv_std    0.076490
# 7   accelY_filtered_deriv_std    0.071802
# 16                    corr_xy    0.058941
# 10        accelY_filtered_var    0.057972
# 15        accelZ_filtered_var    0.056989
# 0                         SMA    0.055688
# 8      accelY_filtered_energy    0.055657
# ✅ with_audio → only_audio @ 2s | Positives in test set: 139776
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.084960
# 2   accelX_filtered_deriv_std    0.083718
# 17                    corr_xz    0.083142
# 12  accelZ_filtered_deriv_std    0.076490
# 7   accelY_filtered_deriv_std    0.071802
# 16                    corr_xy    0.058941
# 10        accelY_filtered_var    0.057972
# 15        accelZ_filtered_var    0.056989
# 0                         SMA    0.055688
# 8      accelY_filtered_energy    0.055657
# ✅ no_audio → with_audio @ 2s | Positives in test set: 28012
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.104241
# 12  accelZ_filtered_deriv_std    0.097977
# 17                    corr_xz    0.068009
# 7   accelY_filtered_deriv_std    0.066186
# 15        accelZ_filtered_var    0.058720
# 16                    corr_xy    0.058536
# 13     accelZ_filtered_energy    0.058518
# 2   accelX_filtered_deriv_std    0.057029
# 5         accelX_filtered_var    0.056034
# 3      accelX_filtered_energy    0.056020
# ✅ no_audio → no_audio @ 2s | Positives in test set: 6951
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.106994
# 12  accelZ_filtered_deriv_std    0.097567
# 17                    corr_xz    0.069008
# 7   accelY_filtered_deriv_std    0.065410
# 15        accelZ_filtered_var    0.060240
# 2   accelX_filtered_deriv_std    0.058605
# 5         accelX_filtered_var    0.058491
# 3      accelX_filtered_energy    0.056325
# 13     accelZ_filtered_energy    0.053982
# 16                    corr_xy    0.053010
# ✅ no_audio → only_audio @ 2s | Positives in test set: 139776
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.104241
# 12  accelZ_filtered_deriv_std    0.097977
# 17                    corr_xz    0.068009
# 7   accelY_filtered_deriv_std    0.066186
# 15        accelZ_filtered_var    0.058720
# 16                    corr_xy    0.058536
# 13     accelZ_filtered_energy    0.058518
# 2   accelX_filtered_deriv_std    0.057029
# 5         accelX_filtered_var    0.056034
# 3      accelX_filtered_energy    0.056020
# ✅ only_audio → with_audio @ 2s | Positives in test set: 28012
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.077996
# 2   accelX_filtered_deriv_std    0.073973
# 5         accelX_filtered_var    0.063248
# 3      accelX_filtered_energy    0.061537
# 17                    corr_xz    0.061192
# 13     accelZ_filtered_energy    0.060583
# 7   accelY_filtered_deriv_std    0.060428
# 12  accelZ_filtered_deriv_std    0.059803
# 15        accelZ_filtered_var    0.055943
# 16                    corr_xy    0.054764
# ✅ only_audio → no_audio @ 2s | Positives in test set: 27806
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.077996
# 2   accelX_filtered_deriv_std    0.073973
# 5         accelX_filtered_var    0.063248
# 3      accelX_filtered_energy    0.061537
# 17                    corr_xz    0.061192
# 13     accelZ_filtered_energy    0.060583
# 7   accelY_filtered_deriv_std    0.060428
# 12  accelZ_filtered_deriv_std    0.059803
# 15        accelZ_filtered_var    0.055943
# 16                    corr_xy    0.054764
# ✅ only_audio → only_audio @ 2s | Positives in test set: 34944
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 18                    corr_yz    0.080502
# 2   accelX_filtered_deriv_std    0.075835
# 13     accelZ_filtered_energy    0.062825
# 5         accelX_filtered_var    0.062689
# 12  accelZ_filtered_deriv_std    0.061383
# 3      accelX_filtered_energy    0.060734
# 7   accelY_filtered_deriv_std    0.059374
# 17                    corr_xz    0.058890
# 15        accelZ_filtered_var    0.056469
# 8      accelY_filtered_energy    0.052278
# ✅ with_audio → with_audio @ 10s | Positives in test set: 7003
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 12  accelZ_filtered_deriv_std    0.110244
# 17                    corr_xz    0.108146
# 2   accelX_filtered_deriv_std    0.107783
# 0                         SMA    0.089766
# 18                    corr_yz    0.077052
# 7   accelY_filtered_deriv_std    0.069622
# 5         accelX_filtered_var    0.067307
# 3      accelX_filtered_energy    0.060647
# 15        accelZ_filtered_var    0.047740
# 10        accelY_filtered_var    0.046853
# ✅ with_audio → no_audio @ 10s | Positives in test set: 27806
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.117178
# 12  accelZ_filtered_deriv_std    0.113873
# 17                    corr_xz    0.103490
# 18                    corr_yz    0.083969
# 0                         SMA    0.073498
# 7   accelY_filtered_deriv_std    0.072760
# 5         accelX_filtered_var    0.069725
# 3      accelX_filtered_energy    0.056003
# 15        accelZ_filtered_var    0.050921
# 13     accelZ_filtered_energy    0.049767
# ✅ with_audio → only_audio @ 10s | Positives in test set: 139776
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.117178
# 12  accelZ_filtered_deriv_std    0.113873
# 17                    corr_xz    0.103490
# 18                    corr_yz    0.083969
# 0                         SMA    0.073498
# 7   accelY_filtered_deriv_std    0.072760
# 5         accelX_filtered_var    0.069725
# 3      accelX_filtered_energy    0.056003
# 15        accelZ_filtered_var    0.050921
# 13     accelZ_filtered_energy    0.049767
# ✅ no_audio → with_audio @ 10s | Positives in test set: 28012
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.123217
# 18                    corr_yz    0.107778
# 12  accelZ_filtered_deriv_std    0.088356
# 5         accelX_filtered_var    0.082029
# 7   accelY_filtered_deriv_std    0.080630
# 3      accelX_filtered_energy    0.073846
# 17                    corr_xz    0.065151
# 0                         SMA    0.060156
# 13     accelZ_filtered_energy    0.058252
# 15        accelZ_filtered_var    0.055930
# ✅ no_audio → no_audio @ 10s | Positives in test set: 6951
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.126357
# 18                    corr_yz    0.113185
# 12  accelZ_filtered_deriv_std    0.085475
# 7   accelY_filtered_deriv_std    0.082596
# 3      accelX_filtered_energy    0.078373
# 5         accelX_filtered_var    0.076813
# 17                    corr_xz    0.067112
# 15        accelZ_filtered_var    0.057502
# 13     accelZ_filtered_energy    0.055480
# 16                    corr_xy    0.051445
# ✅ no_audio → only_audio @ 10s | Positives in test set: 139776
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.123217
# 18                    corr_yz    0.107778
# 12  accelZ_filtered_deriv_std    0.088356
# 5         accelX_filtered_var    0.082029
# 7   accelY_filtered_deriv_std    0.080630
# 3      accelX_filtered_energy    0.073846
# 17                    corr_xz    0.065151
# 0                         SMA    0.060156
# 13     accelZ_filtered_energy    0.058252
# 15        accelZ_filtered_var    0.055930
# ✅ only_audio → with_audio @ 10s | Positives in test set: 28012
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.118728
# 12  accelZ_filtered_deriv_std    0.091079
# 18                    corr_yz    0.089523
# 7   accelY_filtered_deriv_std    0.085764
# 15        accelZ_filtered_var    0.072483
# 13     accelZ_filtered_energy    0.069342
# 17                    corr_xz    0.069143
# 3      accelX_filtered_energy    0.062720
# 5         accelX_filtered_var    0.057026
# 8      accelY_filtered_energy    0.053268
# ✅ only_audio → no_audio @ 10s | Positives in test set: 27806
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.118728
# 12  accelZ_filtered_deriv_std    0.091079
# 18                    corr_yz    0.089523
# 7   accelY_filtered_deriv_std    0.085764
# 15        accelZ_filtered_var    0.072483
# 13     accelZ_filtered_energy    0.069342
# 17                    corr_xz    0.069143
# 3      accelX_filtered_energy    0.062720
# 5         accelX_filtered_var    0.057026
# 8      accelY_filtered_energy    0.053268
# ✅ only_audio → only_audio @ 10s | Positives in test set: 34944
#
# 🔍 Top 10 most important features:
#                       feature  importance
# 2   accelX_filtered_deriv_std    0.111220
# 18                    corr_yz    0.092636
# 12  accelZ_filtered_deriv_std    0.088980
# 7   accelY_filtered_deriv_std    0.078761
# 15        accelZ_filtered_var    0.077338
# 13     accelZ_filtered_energy    0.068493
# 17                    corr_xz    0.068192
# 3      accelX_filtered_energy    0.064943
# 5         accelX_filtered_var    0.063186
# 10        accelY_filtered_var    0.051316
#    train_modality test_modality  duration_s  accuracy  f1_macro  precision_1  \
# 0      with_audio    with_audio           1  0.841687  0.702988     0.365410
# 1      with_audio      no_audio           1  0.785920  0.563492     0.193602
# 2      with_audio    only_audio           1  0.783421  0.555912     0.183629
# 3        no_audio    with_audio           1  0.748626  0.545141     0.172563
# 4        no_audio      no_audio           1  0.792623  0.655829     0.300816
# 5        no_audio    only_audio           1  0.740496  0.521567     0.143234
# 6      only_audio    with_audio           1  0.746512  0.538674     0.164563
# 7      only_audio      no_audio           1  0.741103  0.523253     0.145348
# 8      only_audio    only_audio           1  0.799837  0.669141     0.315537
# 9      with_audio    with_audio           2  0.848841  0.717371     0.382640
# 10     with_audio      no_audio           2  0.806768  0.579569     0.217278
# 11     with_audio    only_audio           2  0.526510  0.460056     0.588855
# 12       no_audio    with_audio           2  0.793662  0.583315     0.219422
# 13       no_audio      no_audio           2  0.843705  0.710241     0.372806
# 14       no_audio    only_audio           2  0.520340  0.456411     0.564749
# 15     only_audio    with_audio           2  0.680260  0.505477     0.140351
# 16     only_audio      no_audio           2  0.674909  0.491773     0.124490
# 17     only_audio    only_audio           2  0.684166  0.684093     0.678739
# 18     with_audio    with_audio          10  0.978853  0.946242     0.825436
# 19     with_audio      no_audio          10  0.901213  0.632340     0.513516
# 20     with_audio    only_audio          10  0.511654  0.373121     0.694856
# 21       no_audio    with_audio          10  0.884817  0.699905     0.433993
# 22       no_audio      no_audio          10  0.932534  0.852558     0.599455
# 23       no_audio    only_audio          10  0.518136  0.416069     0.610699
# 24     only_audio    with_audio          10  0.705824  0.557042     0.197021
# 25     only_audio      no_audio          10  0.692427  0.527076     0.163795
# 26     only_audio    only_audio          10  0.694683  0.694625     0.700194
#
#     recall_1      f1_1  y_te_positives  \
# 0   0.791661  0.500023            7003
# 1   0.360426  0.251898           27806
# 2   0.338329  0.238054           27955
# 3   0.398900  0.240910           28012
# 4   0.810962  0.438848            6951
# 5   0.320193  0.197928           27955
# 6   0.376517  0.229026           28012
# 7   0.325613  0.200981           27806
# 8   0.856632  0.461195            6989
# 9   0.834071  0.524609            7003
# 10  0.358268  0.270504           27806
# 11  0.175688  0.270632          139776
# 12  0.415822  0.287261           28012
# 13  0.825205  0.513587            6951
# 14  0.177405  0.269996          139776
# 15  0.428781  0.211480           28012
# 16  0.373121  0.186691           27806
# 17  0.699348  0.688889           34944
# 18  1.000000  0.904371            7003
# 19  0.230238  0.317930           27806
# 20  0.041559  0.078428          139776
# 21  0.499250  0.464340           28012
# 22  0.980291  0.743968            6951
# 23  0.100053  0.171937          139776
# 24  0.631372  0.300325           28012
# 25  0.505646  0.247437           27806
# 26  0.680918  0.690422           34944
#
#                                   feature_importances
# 0                          feature  importance
# 0  ...
# 1                          feature  importance
# 0  ...
# 2                          feature  importance
# 0  ...
# 3                          feature  importance
# 0  ...
# 4                          feature  importance
# 0  ...
# 5                          feature  importance
# 0  ...
# 6                          feature  importance
# 0  ...
# 7                          feature  importance
# 0  ...
# 8                          feature  importance
# 0  ...
# 9                          feature  importance
# 0  ...
# 10                         feature  importance
# 0  ...
# 11                         feature  importance
# 0  ...
# 12                         feature  importance
# 0  ...
# 13                         feature  importance
# 0  ...
# 14                         feature  importance
# 0  ...
# 15                         feature  importance
# 0  ...
# 16                         feature  importance
# 0  ...
# 17                         feature  importance
# 0  ...
# 18                         feature  importance
# 0  ...
# 19                         feature  importance
# 0  ...
# 20                         feature  importance
# 0  ...
# 21                         feature  importance
# 0  ...
# 22                         feature  importance
# 0  ...
# 23                         feature  importance
# 0  ...
# 24                         feature  importance
# 0  ...
# 25                         feature  importance
# 0  ...
# 26                         feature  importance
# 0  ...

# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score

def train_centered_test_balanced(
    modality: str,
    duration_s: int,
    cfg: dict = None,
):
    """
    Train using event-centered windows, test on balanced sliding windows
    (both from the same modality).
    """
    # Hiperparámetros
    defaults = {"n_estimators": 100, "max_depth": 10, "random_state": 42}
    params = defaults.copy()
    if cfg:
        params.update(cfg)

    # Paths
    path_train = f"./features/fixed/{modality}/features_{modality}_{duration_s}s.csv"
    path_test  = f"./features/fixed_really/{modality}/features_{modality}_{duration_s}s.csv"

    df_tr = pd.read_csv(path_train)
    df_te = pd.read_csv(path_test)

    # Drop metadata
    drop_cols = [
        "video_id", "segment", "participant", "start_time", "end_time",
        "label", "original_cont_duration", "duration_s", "real_sample_count",
        "expected_sample_count", "padding_applied"
    ]
    feat_cols = sorted(set(df_tr.columns) & set(df_te.columns) - set(drop_cols))

    # Features & labels
    X_tr, y_tr = df_tr[feat_cols].fillna(0), df_tr["label"]
    X_te, y_te = df_te[feat_cols].fillna(0), df_te["label"]

    # Entrenamiento
    clf = RandomForestClassifier(
        n_estimators=params["n_estimators"],
        max_depth=params["max_depth"],
        class_weight="balanced",
        random_state=params["random_state"],
        n_jobs=-1
    )
    clf.fit(X_tr, y_tr)
    preds = clf.predict(X_te)

    report = classification_report(y_te, preds, output_dict=True, zero_division=0)
    f1_macro = f1_score(y_te, preds, average="macro")
    report_1 = report.get("1", {"precision": 0, "recall": 0, "f1-score": 0})
    y_te_pos = (y_te == 1).sum()

    metrics = {
        "modality":    modality,
        "duration_s":  duration_s,
        "accuracy":    report["accuracy"],
        "f1_macro":    f1_macro,
        "precision_1": report_1["precision"],
        "recall_1":    report_1["recall"],
        "f1_1":        report_1["f1-score"],
        "y_te_positives": y_te_pos
    }
    print(f"✅ {modality} @ {duration_s}s → Positives in test set: {y_te_pos}")

    return metrics

# %%
# %%
modalities = ["with_audio", "only_audio", "no_audio"]
durations  = [1, 2, 10]

results = []
for mod in modalities:
    for dur in durations:
        res = train_centered_test_balanced(
            modality=mod,
            duration_s=dur,
        )
        results.append(res)

df_results = pd.DataFrame(results)
df_results.to_csv("centered_train_test_balanced_summary.csv", index=False)
df_results
# Out:
# ✅ with_audio @ 1s → Positives in test set: 3608
# ✅ with_audio @ 2s → Positives in test set: 4767
# ✅ with_audio @ 10s → Positives in test set: 6413
# ✅ only_audio @ 1s → Positives in test set: 4546
# ✅ only_audio @ 2s → Positives in test set: 5992
# ✅ only_audio @ 10s → Positives in test set: 8200
# ✅ no_audio @ 1s → Positives in test set: 2444
# ✅ no_audio @ 2s → Positives in test set: 2005
# ✅ no_audio @ 10s → Positives in test set: 613
#      modality  duration_s  accuracy  f1_macro  precision_1  recall_1  \
# 0  with_audio           1  0.982772  0.500376     0.018196  0.006375
# 1  with_audio           2  0.981601  0.497098     0.022222  0.001888
# 2  with_audio          10  0.977107  0.494210     0.000000  0.000000
# 3  only_audio           1  0.976512  0.500076     0.019048  0.008799
# 4  only_audio           2  0.976741  0.496565     0.029520  0.002670
# 5  only_audio          10  0.970517  0.492761     0.043478  0.000244
# 6    no_audio           1  0.983518  0.503578     0.016282  0.014730
# 7    no_audio           2  0.990200  0.500819     0.012195  0.004489
# 8    no_audio          10  0.997328  0.500673     0.007576  0.001631
#
#        f1_1  y_te_positives
# 0  0.009442            3608
# 1  0.003480            4767
# 2  0.000000            6413
# 3  0.012037            4546
# 4  0.004897            5992
# 5  0.000485            8200
# 6  0.015467            2444
# 7  0.006562            2005
# 8  0.002685             613

# %%
import os
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, f1_score

def train_segmentation_test_sliding(
    modality: str,
    duration_s: int,
    train_segmentation: str,  # "centered" or "padded"
    cfg: dict = None,
):
    """
    Train using either 'centered' or 'padded' segments, test on sliding windows
    (same modality and duration).
    """
    # Hyperparameters
    defaults = {"n_estimators": 100, "max_depth": 10, "random_state": 42}
    params = defaults.copy()
    if cfg:
        params.update(cfg)

    # Paths based on train segmentation
    if train_segmentation == "centered":
        path_train = f"./features/from_centered/{modality}/{duration_s}s/annotations_{modality}_centered_{duration_s}s.csv"
    elif train_segmentation == "padded":
        path_train = f"./features/fixed/{modality}/features_{modality}_{duration_s}s.csv"
    else:
        raise ValueError("train_segmentation must be 'centered' or 'padded'")

    path_test = f"./features/fixed_really/balanced/{modality}/features_{modality}_{duration_s}s_balanced.csv"

    # Load data
    df_train = pd.read_csv(path_train)
    df_test  = pd.read_csv(path_test)

    # Drop metadata columns
    drop_cols = [
        "video_id", "segment", "participant", "start_time", "end_time",
        "label", "original_cont_duration", "duration_s", "real_sample_count",
        "expected_sample_count", "padding_applied"
    ]
    feat_cols = sorted(set(df_train.columns) & set(df_test.columns) - set(drop_cols))

    # Features & labels
    X_tr, y_tr = df_train[feat_cols].fillna(0), df_train["label"]
    X_te, y_te = df_test[feat_cols].fillna(0), df_test["label"]

    # Train
    clf = RandomForestClassifier(
        n_estimators=params["n_estimators"],
        max_depth=params["max_depth"],
        class_weight="balanced",
        random_state=params["random_state"],
        n_jobs=-1
    )
    clf.fit(X_tr, y_tr)
    preds = clf.predict(X_te)

    # Evaluation
    report = classification_report(y_te, preds, output_dict=True, zero_division=0)
    f1_macro = f1_score(y_te, preds, average="macro")
    report_1 = report.get("1", {"precision": 0, "recall": 0, "f1-score": 0})
    y_te_pos = (y_te == 1).sum()

    metrics = {
        "modality":          modality,
        "duration_s":        duration_s,
        "train_segmentation": train_segmentation,
        "test_segmentation":  "sliding",
        "accuracy":          report["accuracy"],
        "f1_macro":          f1_macro,
        "precision_1":       report_1["precision"],
        "recall_1":          report_1["recall"],
        "f1_1":              report_1["f1-score"],
        "y_te_positives":    y_te_pos
    }

    print(f"✅ {train_segmentation} → sliding | {modality} @ {duration_s}s → Positives in test set: {y_te_pos}")

    return metrics

# %%
modalities = ["with_audio", "only_audio", "no_audio"]
durations  = [1, 2, 10]
train_strategies = ["centered", "padded"]

results = []
for train_seg in train_strategies:
    for mod in modalities:
        for dur in durations:
            res = train_segmentation_test_sliding(
                modality=mod,
                duration_s=dur,
                train_segmentation=train_seg,
            )
            results.append(res)

df_results = pd.DataFrame(results)
df_results.to_csv("segmentation_train_test_sliding_summary.csv", index=False)
df_results
# Out:
# ✅ centered → sliding | with_audio @ 1s → Positives in test set: 28012
# ✅ centered → sliding | with_audio @ 2s → Positives in test set: 28012
# ✅ centered → sliding | with_audio @ 10s → Positives in test set: 28012
# ✅ centered → sliding | only_audio @ 1s → Positives in test set: 27955
# ✅ centered → sliding | only_audio @ 2s → Positives in test set: 139776
# ✅ centered → sliding | only_audio @ 10s → Positives in test set: 139776
# ✅ centered → sliding | no_audio @ 1s → Positives in test set: 27806
# ✅ centered → sliding | no_audio @ 2s → Positives in test set: 27806
# ✅ centered → sliding | no_audio @ 10s → Positives in test set: 27806
# ✅ padded → sliding | with_audio @ 1s → Positives in test set: 28012
# ✅ padded → sliding | with_audio @ 2s → Positives in test set: 28012
# ✅ padded → sliding | with_audio @ 10s → Positives in test set: 28012
# ✅ padded → sliding | only_audio @ 1s → Positives in test set: 27955
# ✅ padded → sliding | only_audio @ 2s → Positives in test set: 139776
# ✅ padded → sliding | only_audio @ 10s → Positives in test set: 139776
# ✅ padded → sliding | no_audio @ 1s → Positives in test set: 27806
# ✅ padded → sliding | no_audio @ 2s → Positives in test set: 27806
# ✅ padded → sliding | no_audio @ 10s → Positives in test set: 27806
#       modality  duration_s train_segmentation test_segmentation  accuracy  \
# 0   with_audio           1           centered           sliding  0.675623
# 1   with_audio           2           centered           sliding  0.709347
# 2   with_audio          10           centered           sliding  0.815566
# 3   only_audio           1           centered           sliding  0.721279
# 4   only_audio           2           centered           sliding  0.510492
# 5   only_audio          10           centered           sliding  0.520261
# 6     no_audio           1           centered           sliding  0.661243
# 7     no_audio           2           centered           sliding  0.631380
# 8     no_audio          10           centered           sliding  0.766881
# 9   with_audio           1             padded           sliding  0.893302
# 10  with_audio           2             padded           sliding  0.898800
# 11  with_audio          10             padded           sliding  0.900299
# 12  only_audio           1             padded           sliding  0.889859
# 13  only_audio           2             padded           sliding  0.500172
# 14  only_audio          10             padded           sliding  0.500039
# 15    no_audio           1             padded           sliding  0.891079
# 16    no_audio           2             padded           sliding  0.897818
# 17    no_audio          10             padded           sliding  0.899922
#
#     f1_macro  precision_1  recall_1      f1_1  y_te_positives
# 0   0.495010     0.128459  0.387905  0.193003           28012
# 1   0.498985     0.121756  0.306868  0.174340           28012
# 2   0.541331     0.166962  0.211659  0.186673           28012
# 3   0.509689     0.132384  0.321803  0.187594           27955
# 4   0.469017     0.523789  0.231012  0.320619          139776
# 5   0.475634     0.548641  0.228530  0.322660          139776
# 6   0.486588     0.123110  0.389952  0.187139           27806
# 7   0.473269     0.118566  0.417500  0.184683           27806
# 8   0.537764     0.160341  0.314213  0.212331           27806
# 9   0.485477     0.154836  0.015029  0.027399           28012
# 10  0.474859     0.101655  0.001535  0.003024           28012
# 11  0.477418     0.837398  0.003677  0.007322           28012
# 12  0.487563     0.136818  0.019102  0.033524           27955
# 13  0.335649     0.536364  0.002533  0.005041          139776
# 14  0.333542     0.612245  0.000215  0.000429          139776
# 15  0.494684     0.188238  0.026937  0.047129           27806
# 16  0.480886     0.213409  0.008128  0.015659           27806
# 17  0.473663     0.000000  0.000000  0.000000           27806
